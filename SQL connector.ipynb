# %%
pip install mysql-connector-python --q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Mh20dk#1234567890"
)

# Create a cursor
cursor = conn.cursor()

# Create  database
cursor.execute("CREATE DATABASE IF NOT EXISTS FreightCompany")
print("Database created successfully")
# Out:
# Database created successfully

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Mh20dk#1234567890",
    database="FreightCompany"
)

# %%
cursor = conn.cursor()

# %%
from sqlalchemy import create_engine

# connection string
connection_string = 'mysql+pymysql://root:Mh20dk#1234567890@127.0.0.1:3306/FreightCompany'

# %%
customers=pd.read_csv("customers_df.csv")
customers
# Out:
#    CustomerID                          Name           ContactNumber  \
# 0      Y9SILG     Allen, Walker and Stewart     (773)349-6453x57591
# 1      WHIDJB        Miles, Welch and Boone  001-417-740-1935x98471
# 2      1R45S8                 Johnson-Ochoa            633.526.5132
# 3      EZYKQ6   Clark, Freeman and Chambers        578.888.2558x176
# 4      YXGS0F                 Jackson Group  001-455-630-1463x52475
# ..        ...                           ...                     ...
# 95     8JZ5RU  Dodson, Rodriguez and Willis              4066550443
# 96     DA5IB0                    Clarke Inc              7824735169
# 97     22AH8U              Fitzgerald-Floyd       546-678-2813x3271
# 98     7XT2DR    Goodman, Dixon and Vazquez      (268)976-2550x3213
# 99     7KM8WZ      Silva, Roberts and Lewis      (679)407-6772x2174
#
#             State                  City               Country  PinCode  \
# 0         Montana   Lake Williamchester           New Zealand    21905
# ...

# %%
# Create Customers table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Customers (
    CustomerID VARCHAR(100),
    Name VARCHAR(255), 
    ContactNumber VARCHAR(100),
    State VARCHAR(100),
    City VARCHAR(100),
    Country VARCHAR(100),
    PinCode VARCHAR(20),
    Email VARCHAR(100),
    Address VARCHAR(255)
)
""")

# %%
pip install pymysql --q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
engine = create_engine(connection_string)

# %%
customers.to_sql('Customers', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Akanksha\AppData\Local\Temp\ipykernel_18852\762371531.py:1: UserWarning: The provided table name 'Customers' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   customers.to_sql('Customers', con=engine, if_exists='append', index=False)
# 100

# %%
fleet_details  = pd.read_csv("fleet_details_df.csv")
fleet_details
# Out:
#    FleetID VehicleType  Capacity PurchaseDate LastMaintenanceDate  \
# 0   7MDSZ6         Van       534   2023-11-04          2024-04-19
# 1   NRCKIX         Van      1573   2020-01-10          2023-09-24
# 2   INHUXN         Van      1241   2017-10-12          2024-05-17
# 3   MN1NT2       Truck       914   2022-09-13          2023-12-20
# 4   G8UIDK       Truck      1983   2016-10-15          2024-04-20
# 5   IBMOEA         Van      1046   2019-10-08          2023-08-02
# 6   CBIXMS         Van       566   2015-11-04          2024-01-13
# 7   E9NRIB         Van      1674   2018-12-10          2024-03-11
# 8   2DV2I9       Truck       581   2020-06-15          2024-02-02
# 9   NK01F0       Truck      1224   2015-11-17          2023-06-01
# 10  ECI55R         Van      1308   2024-05-02          2024-04-20
# 11  O5HVFJ         Van       541   2015-10-29          2023-05-25
# 12  ESJYLP         Van      1688   2016-03-05          2023-06-04
# ...

# %%
# Create Fleet table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Fleet (
    FleetID VARCHAR(100),
    VehicleType VARCHAR(50), 
    Capacity INT,
    PurchaseDate DATE,
    LastMaintenanceDate DATE,
    Status VARCHAR(100)
    )
""")
print("Fleet table created successfully")
# Out:
# Fleet table created successfully

# %%
fleet_details.to_sql('Fleet', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Akanksha\AppData\Local\Temp\ipykernel_18852\553165298.py:1: UserWarning: The provided table name 'Fleet' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   fleet_details.to_sql('Fleet', con=engine, if_exists='append', index=False)
# 50

# %%
drivers  = pd.read_csv("drivers_df.csv")
drivers
# Out:
#    DriverID                Name           ContactNumber DateOfBirth  \
# 0    DCMV52       Nancy Harding      946.244.8455x89497  1960-11-19
# 1    OXDOOY     Michael Mathews     +1-263-481-6134x407  1983-07-22
# 2    8LCK78     Michael Wallace    001-688-800-1231x198  1997-01-04
# 3    W4500H          Erin Burns   001-357-723-0935x7296  1956-06-02
# 4    2DAZWF     Richard Vazquez           (490)331-3747  1993-01-31
# 5    YHZKFS      Anthony Jordan      483.653.4098x23457  1997-08-29
# 6    2RTHB9           Ryan Horn        601-641-6582x951  1992-01-11
# 7    Q9KV37       Jerry Johnson      634-796-5538x68931  1981-10-07
# 8    LV1SXZ        Kendra Brown     (813)396-1558x52952  1967-06-19
# 9    PYYROB     Matthew Gardner   +1-552-527-1814x85649  1961-11-07
# 10   BPNURT        Michelle Lee              3623356110  1959-05-13
# 11   EBY6B7       Brandy Kramer            573.227.1655  1998-10-06
# 12   KEVFJT        Anne Johnson        897.405.8690x194  1973-06-30
# ...

# %%
# Create Drivers table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Drivers (
    DriverID VARCHAR(100),
    Name VARCHAR(100), 
    ContactNumber VARCHAR(100),
    DateOfBirth DATE,
    LicenseNumber VARCHAR(50),
    HireDate DATE,
    Status VARCHAR(50),
    Experience INT
    )
""")
print("Drivers table created successfully")
# Out:
# Drivers table created successfully

# %%
drivers.to_sql('Drivers', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Akanksha\AppData\Local\Temp\ipykernel_18852\4085235025.py:1: UserWarning: The provided table name 'Drivers' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   drivers.to_sql('Drivers', con=engine, if_exists='append', index=False)
# 50

# %%
routes  = pd.read_csv("routes_df.csv")
routes
# Out:
#    RouteID FleetID               Origin       Destination  Distance  \
# 0   FG7T0O  ESJYLP        New Kaylaview    West Sarahview      1654
# 1   D3IKWO  7MDSZ6        Nicholasmouth         Annehaven       279
# 2   T3K0HA  ECI55R       South Lisaport     North Kathryn       376
# 3   M606V3  2DV2I9          Marquezview  Lake Austinshire      1622
# 4   H18E6V  A24VVF            Dunnshire     North Loriton       462
# ..     ...     ...                  ...               ...       ...
# 95  DP88Q4  4ZK8A8           Reginaport   North Jaredbury       651
# 96  QJMRW9  YNBMJK   South Jenniferview     Armstrongside      1236
# 97  YNU8XI  NK01F0        West Deanfort        Bryantberg       567
# 98  ORKNLI  NK01F0           Carterside        Sherylbury      1754
# 99  ILPJ0Z  MN1NT2  East Matthewborough    South Kimberly      1469
#
#     EstimatedTime
# 0              11
# 1              14
# 2              30
# 3              14
# 4               1
# ..            ...
# ...

# %%
# Create Routes table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Routes (
    RouteID VARCHAR(100),
    FleetID VARCHAR(100), 
    Origin VARCHAR(100),
    Destination VARCHAR(100),
    Distance INT,
    EstimatedTime INT
    )
""")
print("Routes table created successfully")
# Out:
# Routes table created successfully

# %%
routes.to_sql('Routes', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Akanksha\AppData\Local\Temp\ipykernel_18852\2492429713.py:1: UserWarning: The provided table name 'Routes' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   routes.to_sql('Routes', con=engine, if_exists='append', index=False)
# 100

# %%
shipments  = pd.read_csv("shipments_df.csv")
shipments
# Out:
#     ShipmentID CustomerID RouteID DriverID FleetID ShipmentDate DeliveryDate  \
# 0    R273AC7H6     Y9SILG  MPEUF5   AT4WI9  5E4RWI   2023-11-15   2024-05-28
# 1    5DSRAZNMD     PNLW6A  86DZJI   OXDOOY  G8YY6T   2023-08-07   2023-10-05
# 2    YKOCQK61Z     7KM8WZ  J5DVLW   LG56GN  NRCKIX   2023-12-28   2024-05-23
# 3    4Z2UER0XR     KOX4N7  IS3FEC   AI90B7  NRCKIX   2023-12-27   2024-06-01
# 4    59XXZNNHH     I77V8Q  HNEJF7   AI90B7  ECI55R   2024-02-26   2024-04-10
# ..         ...        ...     ...      ...     ...          ...          ...
# 495  0XTPOJ8T3     E2DNUP  CKEVIM   0DAS2F  MN1NT2   2024-05-02   2024-05-06
# 496  E83VO8HPD     SCC85L  K75L0B   BLN7Q3  N2ODZ2   2023-07-07   2024-01-30
# 497  PMXY2QY8Z     E3X1LD  I8IDTW   AT4WI9  3AKH0M   2023-08-29   2024-04-14
# 498  XOXS38DXE     VJ81VL  4TWWVZ   CYDAF7  HVFITV   2024-04-03   2024-05-09
# 499  URJVFQYVC     MH8NIL  66KTPA   OXDOOY  YF64H4   2023-12-29   2024-03-07
#
#          Status  Weight     Volume
# ...

# %%
# Create Shipments table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Shipments (
    ShipmentID VARCHAR(100),
    CustomerID VARCHAR(100), 
    RouteID VARCHAR(50),
    DriverID VARCHAR(50),
    FleetID VARCHAR(50),
    ShipmentDate DATE,
    DeliveryDate DATE,
    Status VARCHAR(50),
    Weight INT,
    Volume FLOAT
    )
""")
print("Shipments table created successfully")
# Out:
# Shipments table created successfully

# %%
shipments.to_sql('Shipments', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Akanksha\AppData\Local\Temp\ipykernel_18852\3372796324.py:1: UserWarning: The provided table name 'Shipments' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   shipments.to_sql('Shipments', con=engine, if_exists='append', index=False)
# 500

# %%
delivery_times  = pd.read_csv("delivery_times_df.csv")
delivery_times
# Out:
#     DeliveryID ShipmentID CustomerID RouteID FleetID  \
# 0    XL692LBB7  R273AC7H6     Y9SILG  MPEUF5  5E4RWI
# 1    AAVF8UYJJ  5DSRAZNMD     PNLW6A  86DZJI  G8YY6T
# 2    5V61FXSA3  YKOCQK61Z     7KM8WZ  J5DVLW  NRCKIX
# 3    KMUSRX39P  4Z2UER0XR     KOX4N7  IS3FEC  NRCKIX
# 4    CY26105DI  59XXZNNHH     I77V8Q  HNEJF7  ECI55R
# ..         ...        ...        ...     ...     ...
# 495  TL29T4IRJ  0XTPOJ8T3     E2DNUP  CKEVIM  MN1NT2
# 496  Y0DJW9P73  E83VO8HPD     SCC85L  K75L0B  N2ODZ2
# 497  RA3EHJ1AN  PMXY2QY8Z     E3X1LD  I8IDTW  3AKH0M
# 498  O4YO5CRSP  XOXS38DXE     VJ81VL  4TWWVZ  HVFITV
# 499  KNI8O5BDK  URJVFQYVC     MH8NIL  66KTPA  YF64H4
#
#           ScheduledDeliveryTime          ActualDeliveryTime       DelayReason
# 0    2024-01-25 13:27:09.000000  2024-02-06 07:47:12.000000  Mechanical Issue
# 1    2023-09-01 04:00:13.000000  2023-09-11 05:16:02.000000  Mechanical Issue
# 2    2024-01-27 02:33:27.000000  2024-04-15 03:37:32.000000           Traffic
# ...

# %%
# Create delivery_times table
cursor.execute("""
CREATE TABLE IF NOT EXISTS delivery_times (
    DeliveryID VARCHAR(100),
    ShipmentID VARCHAR(100), 
    CustomerID VARCHAR(50),
    RouteID VARCHAR(50),
    FleetID VARCHAR(50),
    ScheduledDeliveryTime DATETIME,
    ActualDeliveryTime DATETIME,
    DelayReason VARCHAR(255)
    )
""")
print("delivery_times table created successfully")
# Out:
# delivery_times table created successfully

# %%
delivery_times.to_sql('delivery_times', con=engine, if_exists='append', index=False)
# Out:
# 500

# %%
operational_costs  = pd.read_csv("operational_costs_df.csv")
operational_costs
# Out:
#         CostID FleetID        Date     CostType      Amount
# 0    9XDB5DX74  NXCBGE  2024-03-10        Tolls  383.619996
# 1    PGT7PH7Z4  IBMOEA  2024-01-05        Tolls  962.541774
# 2    23EIJ8DIT  5E4RWI  2023-10-02        Tolls  594.216962
# 3    780B2G72B  O5HVFJ  2024-01-31        Tolls  594.137710
# 4    6X7CCII3O  DWXNC9  2023-12-22         Fuel  705.966043
# ..         ...     ...         ...          ...         ...
# 995  CPIC9467N  09PCZR  2023-07-01        Tolls  709.908201
# 996  5A1EZRJ13  ZIH3L4  2023-12-18  Maintenance  747.183986
# 997  U4LKVIEAI  ESJYLP  2024-03-18        Tolls  439.288156
# 998  CF4JDO4KG  54R8KF  2023-06-15         Fuel  122.470627
# 999  E7XR1G087  8MR90N  2023-11-07         Fuel  790.523082
#
# [1000 rows x 5 columns]

# %%
# Create operational_costs table
cursor.execute("""
CREATE TABLE IF NOT EXISTS operational_costs (
    CostID VARCHAR(100),
    FleetID VARCHAR(100), 
    Date DATE,
    CostType VARCHAR(50),
    Amount FLOAT
    )
""")
print("operational_costs table created successfully")
# Out:
# operational_costs table created successfully

# %%
operational_costs.to_sql('operational_costs', con=engine, if_exists='append', index=False)
# Out:
# 1000

# %%
maintenance_records  = pd.read_csv("maintenance_records_df.csv")
maintenance_records
# Out:
#     MaintenanceID FleetID        Date   MaintenanceType         Cost
# 0       HB2K574G3  NJ4DYV  2024-01-11        Oil Change  2231.791305
# 1       EZ53H9IFR  YF64H4  2024-04-30        Oil Change  1118.817686
# 2       3MD10JE22  YNBMJK  2024-02-10     Engine Repair  4080.655948
# 3       KXQTCL3VB  N2ODZ2  2023-10-03  Tire Replacement  3508.820179
# 4       8SGGTLSJP  HEDRH1  2023-10-24        Oil Change  1806.264328
# ..            ...     ...         ...               ...          ...
# 195     1EKVB6PHP  WC00KR  2024-03-31  Tire Replacement  2796.665737
# 196     EAKNM6PZQ  4ZK8A8  2023-09-05        Oil Change  2834.261249
# 197     XQJYP1D83  YNBMJK  2024-04-14     Engine Repair  1492.274205
# 198     BQXIBAGGH  EG4QHC  2023-12-14  Tire Replacement  1470.967491
# 199     WO1DJEXYY  3AKH0M  2023-09-29  Tire Replacement  4658.735936
#
# [200 rows x 5 columns]

# %%
# Create maintenance_records table
cursor.execute("""
CREATE TABLE IF NOT EXISTS maintenance_records (
    MaintenanceID VARCHAR(100),
    FleetID VARCHAR(100), 
    Date DATE,
    MaintenanceType VARCHAR(50),
    Cost FLOAT
    )
""")
print("maintenance_records table created successfully")
# Out:
# maintenance_records table created successfully

# %%
maintenance_records.to_sql('maintenance_records', con=engine, if_exists='append', index=False)
# Out:
# 200
